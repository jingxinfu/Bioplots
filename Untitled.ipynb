# %%
# %load_ext autoreload
# %autoreload 2
import Bioplots as bpt
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import pearsonr
df = bpt.get_rdataset('beaver')
df['day'] = df['day'].map(str)
df['activ'] = df['activ'].map(str)
df['pair'] = list(range(50))*2
ax=bpt.box(df=df,x='day', y="temp",pair='pair',subgroup='activ');
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bpt.box(df=df,x='day', y="temp",pair='pair')
